# %%
import pandas as pd #to form the dataframe
import folium #for rendering the map
import tkinter as tk #for GUI

# %%
    cm_df = pd.DataFrame({'city': ['Mumbai', 'Pune', 'Aurangabad', 'Sangli', 'Nagpur','Nashik','Thane','Buldhana','Ahmednagar','Yavatmal',' Shahdara', 'New Delhi','Noida', 'Meerut','Gautam Budhh Nagar','Agra','Lucknow','Firozabad','Shamli','Moradabad','Saharanpur','Ghaziabad','Kasaragod', 'Kannur','Mallapuram','Ernakulam','Pathanamthitta','Thiruvananthapuram','Chennai', 'Coimbature','Dindigul','Erode','Vellore','Tuticorin','Madurai','Tiruchirapalli','Thiruvarur','Kanyakumari','Hyderabad','Warangal','Nizamabad','Jogulamba Gadwal','Karimnagar','Nirmal','Bhilwara','Jaipur','Jodhpur','Jaisalmer','Kota','Bikaner','Ahmedabad','Surat','Vadodara','Rajkot','Bhavnagar','Bhopal','Indore','Ujjain','Khargone','Hoshangabad','Bengaluru','Mysore','Belagavi','Kurnool','Nellore','Vishakhapatnam','Chittoor','Anantapur','Kolkata','Howrah','Medinipur East','Siwan','Chandigarh','Korba','Gurugram','Palwal','Faridabad','Jammu','Udhampur','Srinagar','Bandipora','Baramulla','Khordha','Jalandhar','Pathankot','Shaheed Bhagat Singh Nagar','Dehradun'],#hotspot cities
                          'latitude': [19.075983, 18.520430, 19.876165, 16.852398, 21.145800,19.997453,19.197817,20.523737,19.085455,20.389623,28.671679, 28.626963,28.5726442, 28.916667,27.42397,27.1752554,26.8381,27.1773663,29.5008816,28.8638424,29.9880774,28.711241,12.421713,11.8762254,14.6094453,10.0383947,9.2834044,8.5058909,13.0801721,10.9961974,10.3303299,11.3692044,12.7948109,8.7235577,9.9223354,10.7620859,10.7361861,8.079252,17.3887859,17.9806094,26.0553179,16.0999202,18.4346438,19.0915209,25.48877352,26.916194,26.2967719,27.0280161,25.1968256,28.0159286,23.0216238,21.1864607,22.2973142,22.3051991,21.7718836,23.2530923,22.7203616,23.174597,21.8187743,22.6001502,12.9791198,12.3051828,15.8572666,15.8309251,14.4493717,17.68009,13.1601048,14.6546235,22.5677459,22.5882216,22.4207025,26.1310043,30.7194022,22.5197695,28.4646148,28.1250257,28.402837,32.7185614,33,34.0747444,34.4563234,34.2050056,85.5605947,31.2920107,32.3017104,31.1268889,30.3255646],#latitudes
                          'longitude': [72.877655, 73.856743, 75.343315, 74.581474, 79.088158,73.789802,72.967810,76.188482,74.735486,78.127160,77.294197, 77.215396,77.3547609, 77.683333,77.09922,78.0098161,78.389912,77.3483826,78.8057783,77.5081299,77.4445372,77.4445372,75.1904498,75.3738043,79.3024381,76.5074145,76.9606628,76.9570481,80.2838331,77.0055029,78.0673979,77.67662691,79.0006411,78.025154,78.1493658,78.712771,79.6331866,77.5499338,78.4610647,79.5982115,82.9931387,77.7341584,79.1322648,78.396609,74.6996128,75.820349,73.0351433,70.7785056,76.0008933,73.3171367,72.5797068,72.8081281,73.1942567,70.8028335,72.1416449,77.3962718,75.8681996,75.7851423,75.6064577,77.9266452,77.5912997,76.6553609,74.5069343,78.0425373,79.9873763,83.20161,79.1555506,77.5562598,88.3476023,88.323139,87.3269963,84.3912566,76.7646552,82.6295146,77.0299194,77.358313,77.3085626,74.8580917,75.166667,74.8204443,75.1834458,74.3622108,85.5605947,75.5680577,75.6586425,76.1576848,78.0436813]  #longitudes
                          })
    print(cm_df)
    map_cm_multiple = folium.Map(location=[18, 80], zoom_start=3)
    for i in cm_df.itertuples():
        folium.Marker(location=[i.latitude, i.longitude],popup=i.city).add_to(map_cm_multiple) #for on map markers
    map_cm_multiple
# Out:
#                           city   latitude  longitude
# 0                       Mumbai  19.075983  72.877655
# 1                         Pune  18.520430  73.856743
# 2                   Aurangabad  19.876165  75.343315
# 3                       Sangli  16.852398  74.581474
# 4                       Nagpur  21.145800  79.088158
# ..                         ...        ...        ...
# 82                     Khordha  85.560595  85.560595
# 83                   Jalandhar  31.292011  75.568058
# 84                   Pathankot  32.301710  75.658642
# 85  Shaheed Bhagat Singh Nagar  31.126889  76.157685
# 86                    Dehradun  30.325565  78.043681
#
# [87 rows x 3 columns]
# ...
